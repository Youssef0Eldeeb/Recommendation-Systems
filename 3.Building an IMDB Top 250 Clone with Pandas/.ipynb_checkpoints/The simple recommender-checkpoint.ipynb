# %%
import pandas as pd
import numpy as np

#Load the dataset into a pandas dataframe
df = pd.read_csv('/Users/youssefeldeeb/Documents/Material/Recommendation_Systems_with_Python/Data/movies_metadata.csv',low_memory=False)
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
# v is the number of votes garnered by the movie
# m is the minimum number of votes required for the movie to be in the chart (the prerequisite)
# R is the mean rating of the movie
# C is the mean rating of all the movies in the dataset

# %%
#Calculate the number of votes garnered by the 80th percentile movie
m = df['vote_count'].quantile(0.80)
m
# Out:
# 50.0

# %%
#Only consider movies longer than 45 minutes and shorter than 300 minutes
q_movies = df[(df['runtime'] >= 45) & (df['runtime'] <= 300)]

#Only consider movies that have garnered more than m votes
q_movies = q_movies[q_movies['vote_count'] >= m]

#Inspect the number of movies that made the cut
q_movies.shape
# Out:
# (8963, 24)

# %%
# Calculate C
C = df['vote_average'].mean()
C
# Out:
# 5.618207215133889

# %%
# Function to compute the IMDB weighted rating for each movie
def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    # Compute the weighted score
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# Compute the score using the weighted_rating function defined above
q_movies['score'] = q_movies.apply(weighted_rating,axis=1)
q_movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5      False                                                NaN  60000000
# ...      ...                                                ...       ...
# 45268  False                                                NaN   5402000
# 45339  False                                                NaN         0
# 45343  False  {'id': 52888, 'name': 'The Visitors Collection...  25868826
# 45348  False                                                NaN         0
# 45441  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# 5      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# ...                                                  ...
# 45268                     [{'id': 35, 'name': 'Comedy'}]
# 45339                     [{'id': 35, 'name': 'Comedy'}]
# 45343                     [{'id': 35, 'name': 'Comedy'}]
# 45348  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 45441                     [{'id': 35, 'name': 'Comedy'}]
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 4                                       NaN   11862  tt0113041
# 5                                       NaN     949  tt0113277
# ...                                     ...     ...        ...
# 45268                                   NaN  277839  tt4531694
# 45339                                   NaN  430365  tt5804948
# 45343                                   NaN  248705  tt2441982
# 45348                                   NaN   44918  tt1640571
# 45441                                   NaN   14008  tt0294425
#
#       original_language                original_title  \
# 0                    en                     Toy Story
# 1                    en                       Jumanji
# 2                    en              Grumpier Old Men
# 4                    en   Father of the Bride Part II
# 5                    en                          Heat
# ...                 ...                           ...
# 45268                fr                       Pattaya
# 45339                fr                À bras ouverts
# 45343                fr  Les Visiteurs: La Révolution
# 45348                en                    Titanic II
# 45441                en                   Cadet Kelly
#
#                                                 overview  ...      revenue  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...  373554033.0
# 1      When siblings Judy and Peter discover an encha...  ...  262797249.0
# 2      A family wedding reignites the ancient feud be...  ...          0.0
# 4      Just when George Banks has recovered from his ...  ...   76578911.0
# 5      Obsessive master thief, Neil McCauley leads a ...  ...  187436818.0
# ...                                                  ...  ...          ...
# 45268  Franky and Krimo dream of leaving the grey gri...  ...          0.0
# 45339  Jean-Étienne Fougerole is an intellectual bohe...  ...          0.0
# 45343  Stuck in the corridors of time, Godefroy de Mo...  ...          0.0
# 45348  On the 100th anniversary of the original voyag...  ...          0.0
# 45441  Hyperactive teenager Kelly is enrolled into a ...  ...          0.0
#
#       runtime                                   spoken_languages    status  \
# 0        81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2       101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4       106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5       170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# ...       ...                                                ...       ...
# 45268   100.0          [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
# 45339    92.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 45343   110.0          [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
# 45348    90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45441   101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 4      Just When His World Is Back To Normal... He's ...
# 5                               A Los Angeles Crime Saga
# ...                                                  ...
# 45268                                                NaN
# 45339                         Thanks for the invitation!
# 45343                                                NaN
# 45348           100 years later, lightning strikes twice
# 45441                            Too Cool For The Rules!
#
#                                                 title  video vote_average  \
# 0                                           Toy Story  False          7.7
# 1                                             Jumanji  False          6.9
# 2                                    Grumpier Old Men  False          6.5
# 4                         Father of the Bride Part II  False          5.7
# 5                                                Heat  False          7.7
# ...                                               ...    ...          ...
# 45268  Good Guys Go to Heaven, Bad Guys Go to Pattaya  False          5.3
# 45339                                  With Open Arms  False          5.2
# 45343                      The Visitors: Bastille Day  False          4.0
# 45348                                       Titanic 2  False          3.4
# 45441                                     Cadet Kelly  False          5.2
#
#       vote_count     score
# 0         5415.0  7.680953
# 1         2413.0  6.873979
# 2           92.0  6.189510
# 4          173.0  5.681661
# 5         1886.0  7.646235
# ...          ...       ...
# 45268      153.0  5.378376
# 45339       94.0  5.345211
# 45343      167.0  4.372859
# 45348       55.0  4.456289
# 45441      145.0  5.307233
#
# [8963 rows x 25 columns]

# %%
q_movies = q_movies.sort_values('score',ascending=False)
q_movies
# Out:
#        adult                              belongs_to_collection     budget  \
# 10309  False                                                NaN   13200000
# 314    False                                                NaN   25000000
# 834    False  {'id': 230, 'name': 'The Godfather Collection'...    6000000
# 40251  False                                                NaN          0
# 12481  False  {'id': 263, 'name': 'The Dark Knight Collectio...  185000000
# ...      ...                                                ...        ...
# 17708  False  {'id': 225961, 'name': 'Birdemic Collection', ...          0
# 12911  False                                                NaN   25000000
# 11557  False                                                NaN   20000000
# 3471   False                                                NaN   44000000
# 13566  False                                                NaN  100000000
#
#                                                   genres  \
# 10309  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 314    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 834    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 40251  [{'id': 10749, 'name': 'Romance'}, {'id': 16, ...
# 12481  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# ...                                                  ...
# 17708  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 12911  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 11557  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3471   [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 13566  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                               homepage      id    imdb_id  \
# 10309                                              NaN   19404  tt0112870
# 314                                                NaN     278  tt0111161
# 834                       http://www.thegodfather.com/     238  tt0068646
# 40251  https://www.funimationfilms.com/movie/yourname/  372058  tt5311514
# 12481     http://thedarkknight.warnerbros.com/dvdsite/     155  tt0468569
# ...                                                ...     ...        ...
# 17708                         http://www.birdemic.com/   40016  tt1316037
# 12911                    http://www.disastermovie.net/   13805  tt1213644
# 11557                                              NaN    9760  tt0799949
# 3471                                               NaN    5491  tt0185183
# 13566                                              NaN   14164  tt1098327
#
#       original_language               original_title  \
# 10309                hi  Dilwale Dulhania Le Jayenge
# 314                  en     The Shawshank Redemption
# 834                  en                The Godfather
# 40251                ja                        君の名は。
# 12481                en              The Dark Knight
# ...                 ...                          ...
# 17708                en   Birdemic: Shock and Terror
# 12911                en               Disaster Movie
# 11557                en                   Epic Movie
# 3471                 en            Battlefield Earth
# 13566                en         Dragonball Evolution
#
#                                                 overview  ...       revenue  \
# 10309  Raj is a rich, carefree, happy-go-lucky second...  ...  1.000000e+08
# 314    Framed in the 1940s for the double murder of h...  ...  2.834147e+07
# 834    Spanning the years 1945 to 1955, a chronicle o...  ...  2.450664e+08
# 40251  High schoolers Mitsuha and Taki are complete s...  ...  3.552983e+08
# 12481  Batman raises the stakes in his war on crime. ...  ...  1.004558e+09
# ...                                                  ...  ...           ...
# 17708  A platoon of eagles and vultures attacks the r...  ...  0.000000e+00
# 12911  In DISASTER MOVIE, the filmmaking team behind ...  ...  1.410928e+07
# 11557  When Edward, Peter, Lucy and Susan each follow...  ...  8.686556e+07
# 3471   In the year 3000, man is no match for the Psyc...  ...  2.140000e+07
# 13566  The young warrior Son Goku sets out on a quest...  ...  0.000000e+00
#
#       runtime                                   spoken_languages    status  \
# 10309   190.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]  Released
# 314     142.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 834     175.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 40251   106.0               [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 12481   152.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# ...       ...                                                ...       ...
# 17708    95.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 12911    87.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11557    86.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3471    118.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 13566    85.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                                  tagline  \
# 10309                               Come... Fall In Love
# 314    Fear can hold you prisoner. Hope can set you f...
# 834                           An offer you can't refuse.
# 40251                                                NaN
# 12481                                    Why So Serious?
# ...                                                  ...
# 17708            Why did the eagles and vultures attack?
# 12911    Your favorite movies are going to be destroyed.
# 11557                     We know it's big. We measured.
# 3471                                Take Back The Planet
# 13566                          The legend comes to life.
#
#                              title  video vote_average vote_count     score
# 10309  Dilwale Dulhania Le Jayenge  False          9.1      661.0  8.855148
# 314       The Shawshank Redemption  False          8.5     8358.0  8.482863
# 834                  The Godfather  False          8.5     6024.0  8.476278
# 40251                   Your Name.  False          8.5     1030.0  8.366584
# 12481              The Dark Knight  False          8.3    12269.0  8.289115
# ...                            ...    ...          ...        ...       ...
# 17708   Birdemic: Shock and Terror  False          2.1       69.0  3.578238
# 12911               Disaster Movie  False          3.1      250.0  3.519701
# 11557                   Epic Movie  False          3.2      334.0  3.514871
# 3471             Battlefield Earth  False          3.0      259.0  3.423658
# 13566         Dragonball Evolution  False          2.9      475.0  3.158877
#
# [8963 rows x 25 columns]

# %%
sample_q_movies = q_movies[['title','vote_count','vote_average','runtime','score']]
sample_q_movies
# Out:
#                              title  vote_count  vote_average  runtime  \
# 10309  Dilwale Dulhania Le Jayenge       661.0           9.1    190.0
# 314       The Shawshank Redemption      8358.0           8.5    142.0
# 834                  The Godfather      6024.0           8.5    175.0
# 40251                   Your Name.      1030.0           8.5    106.0
# 12481              The Dark Knight     12269.0           8.3    152.0
# ...                            ...         ...           ...      ...
# 17708   Birdemic: Shock and Terror        69.0           2.1     95.0
# 12911               Disaster Movie       250.0           3.1     87.0
# 11557                   Epic Movie       334.0           3.2     86.0
# 3471             Battlefield Earth       259.0           3.0    118.0
# 13566         Dragonball Evolution       475.0           2.9     85.0
#
#           score
# 10309  8.855148
# 314    8.482863
# 834    8.476278
# 40251  8.366584
# 12481  8.289115
# ...         ...
# 17708  3.578238
# 12911  3.519701
# 11557  3.514871
# 3471   3.423658
# 13566  3.158877
#
# [8963 rows x 5 columns]
